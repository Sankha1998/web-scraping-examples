# %%
from  bs4 import BeautifulSoup as bs 
# small caps --> lib name, capital --> Class name, as --> alias --> hum payar se bulate hai
import pandas as pd
import requests 
import re

# %%
import re
regex = re.compile(r'<[^>]+>')
def remove_html(string):
    return regex.sub('', string)

# %% [markdown]
# <H5> request types : </H5>
#
# - GET
# - POST
# - PUT
# - DELETE

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'}

# %%
url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250'

# %%
webpage = requests.get(url, headers=headers).text
soup = bs(webpage, 'lxml')

# %%
res=soup.find('tbody',class_='lister-list') # find all takes two input parameters --> html tags, class, id, href

# %%
res
# Out:
# <tbody class="lister-list">
# <tr>
# <td class="posterColumn">
# <span data-value="1" name="rk"></span>
# <span data-value="9.236029366728056" name="ir"></span>
# <span data-value="7.791552E11" name="us"></span>
# <span data-value="2739821" name="nv"></span>
# <span data-value="-1.7639706332719438" name="ur"></span>
# <a href="/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=1a264172-ae11-42e4-8ef7-7fed1973bb8f&amp;pf_rd_r=W1TPET48VVKKRP2ZREPT&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_1"> <img alt="The Shawshank Redemption" height="67" src="https://m.media-amazon.com/images/M/MV5BNDE3ODcxYzMtY2YzZC00NmNlLWJiNDMtZDViZWM2MzIxZDYwXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       1.
# ...

# %%
c = 1
for i,j in zip(res.find_all('td',class_='titleColumn'),res.find_all('td',class_='imdbRating')):
    print(c," ".join(i.text.strip().split()).split('(')[0].split('.')[1].strip()," ".join(i.text.strip().split()).split('(')[1].strip(')'), j.text.strip())
    c
# Out:
# 1 The Shawshank Redemption 1994 9.2
# 1 The Godfather 1972 9.2
# 1 The Dark Knight 2008 9.0
# 1 The Godfather Part II 1974 9.0
# 1 12 Angry Men 1957 9.0
# 1 Schindler's List 1993 8.9
# 1 The Lord of the Rings: The Return of the King 2003 8.9
# 1 Pulp Fiction 1994 8.8
# 1 The Lord of the Rings: The Fellowship of the Ring 2001 8.8
# 1 Il buono, il brutto, il cattivo 1966 8.8
# 1 Forrest Gump 1994 8.8
# 1 Fight Club 1999 8.7
# 1 The Lord of the Rings: The Two Towers 2002 8.7
# 1 Inception 2010 8.7
# 1 Star Wars: Episode V - The Empire Strikes Back 1980 8.7
# 1 The Matrix 1999 8.7
# 1 GoodFellas 1990 8.7
# 1 One Flew Over the Cuckoo's Nest 1975 8.6
# 1 Se7en 1995 8.6
# 1 It's a Wonderful Life 1946 8.6
# 1 Shichinin no samurai 1954 8.6
# 1 The Silence of the Lambs 1991 8.6
# 1 Saving Private Ryan 1998 8.6
# 1 Cidade de Deus 2002 8.6
# 1 Interstellar 2014 8.6
# 1 La vita è bella 1997 8.6
# 1 The Green Mile 1999 8.6
# 1 Star Wars 1977 8.5
# 1 Terminator 2: Judgment Day 1991 8.5
# ...
